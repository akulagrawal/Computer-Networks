# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import mpld3
#mpld3.enable_notebook()

# %%
df = pd.read_csv('final/K0.600000_p0.500000_B2_INQ.tsv', sep='\t')

# %%
df.head()
# Out:
#    N    p queue  avgPacketDelay  stdPacketDelay  avgIOLinkUtilisation  \
# 0  4  0.5   INQ         3.85930         2.86361              0.040156
# 1  5  0.5   INQ         3.93099         3.07482              0.031936
# 2  6  0.5   INQ         4.06467         3.20477              0.026417
# 3  7  0.5   INQ         4.05101         3.17021              0.022606
# 4  8  0.5   INQ         4.18515         3.32755              0.019841
#
#    avgOLinkUtilisation  avgDropped  KOUQDropProbability
# 0             0.160625    0.003300             0.000000
# 1             0.159680    0.003810             0.000000
# 2             0.158500    0.004142             0.000000
# 3             0.158243    0.003971             0.000000
# 4             0.158725    0.004444             0.000188

# %% [markdown]
# # OLU: Average Output Link Utilization

# %%
for q in ['INQ']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgOLinkUtilisation'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.159, "B = " + B, fontsize=10)
            plt.text(80, 0.158, "p = " + p, fontsize=10)
            plt.text(80, 0.157, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgOLinkUtilisation'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.163, "B = " + B, fontsize=10)
            plt.text(80, 0.162, "p = " + p, fontsize=10)
            plt.text(80, 0.161, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgOLinkUtilisation'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.159, "B = " + B, fontsize=10)
            plt.text(80, 0.158, "p = " + p, fontsize=10)
            plt.text(80, 0.157, "K = " + K, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_p'+p+'_K'+K+'.png')

# %%
for K in ['0.600000']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for q in ['INQ', 'KOUQ', 'iSLIP']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgOLinkUtilisation'], label = 'queue = ' + q)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.1651, "B = " + B, fontsize=10)
            plt.text(80, 0.1647, "K = " + K, fontsize=10)
            plt.text(80, 0.1643, "p = " + p, fontsize=10)
            plt.legend()
            plt.savefig('OLUK'+K+'_p'+p+'_B'+B+'.png')

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgOLinkUtilisation'], label = 'K = ' + K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.1651, "B = " + B, fontsize=10)
            plt.text(80, 0.1648, "p = " + p, fontsize=10)
            plt.text(80, 0.1645, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_p'+p+'_B'+B+'.png')

# %%
for q in ['INQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgOLinkUtilisation'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.13, "K = " + K, fontsize=10)
            plt.text(80, 0.12, "B = " + B, fontsize=10)
            plt.text(80, 0.11, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgOLinkUtilisation'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.13, "K = " + K, fontsize=10)
            plt.text(80, 0.12, "B = " + B, fontsize=10)
            plt.text(80, 0.11, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgOLinkUtilisation'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Output Link Utilization')
            plt.text(80, 0.13, "K = " + K, fontsize=10)
            plt.text(80, 0.12, "B = " + B, fontsize=10)
            plt.text(80, 0.11, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('OLU'+q+'_B'+B+'_K'+K+'.png')

# %% [markdown]
# # IOLU: Average Input-Output Link Utilization

# %%
for B in ['4']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for q in ['INQ', 'KOUQ', 'iSLIP']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgIOLinkUtilisation'], label = 'queue = ' + q)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Input-Output Link Utilization')
            plt.text(80, 0.030, "B = " + B, fontsize=10)
            plt.text(80, 0.027, "K = " + K, fontsize=10)
            plt.text(80, 0.024, "p = " + p, fontsize=10)
            plt.legend()
            plt.savefig('IOLUK'+K+'_p'+p+'_B'+B+'.png')

# %%
for q in ['INQ', 'KOUQ', 'iSLIP']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgIOLinkUtilisation'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Input-Output Link Utilization')
            plt.text(80, 0.030, "K = " + K, fontsize=10)
            plt.text(80, 0.027, "p = " + p, fontsize=10)
            plt.text(80, 0.024, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('IOLU'+q+'_p'+p+'_K'+K+'.png')

# %%
for B in ['4']:
    for p in ['0.500000']:
        for q in ['KOUQ']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'], df['avgIOLinkUtilisation'], label = 'K = ' + K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Input-Output Link Utilization')
            plt.text(80, 0.030, "B = " + B, fontsize=10)
            plt.text(80, 0.027, "p = " + p, fontsize=10)
            plt.text(80, 0.024, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('IOLU'+q+'_p'+p+'_B'+B+'.png')

# %%
for q in ['INQ', 'KOUQ', 'iSLIP']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgIOLinkUtilisation'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Input-Output Link Utilization')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('IOLU'+q+'_B'+B+'_K'+K+'.png')

# %% [markdown]
# # stdPD: Standard Deviation of Packet Delay

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'K = ' + K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 2.04, "B = " + B, fontsize=10)
            plt.text(80, 2.02, "p = " + p, fontsize=10)
            plt.text(80, 2.00, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_p'+p+'_B'+B+'.png')

# %%
for K in ['0.600000']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for q in ['INQ', 'KOUQ', 'iSLIP']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'queue = ' + q)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 3.3, "B = " + B, fontsize=10)
            plt.text(80, 3.0, "K = " + K, fontsize=10)
            plt.text(80, 2.7, "p = " + p, fontsize=10)
            plt.legend()
            plt.savefig('stdPDK'+K+'_p'+p+'_B'+B+'.png')

# %%
for q in ['INQ']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 4.4, "K = " + K, fontsize=10)
            plt.text(80, 4.2, "p = " + p, fontsize=10)
            plt.text(80, 4.0, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 1.59, "K = " + K, fontsize=10)
            plt.text(80, 1.53, "p = " + p, fontsize=10)
            plt.text(80, 1.47, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 4.05, "K = " + K, fontsize=10)
            plt.text(80, 3.875, "p = " + p, fontsize=10)
            plt.text(80, 3.7, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['INQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Packet Delay Standard Deviation')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_B'+B+'_K'+K+'.png')

# %% [markdown]
# # avgPD: Average Packet Delay

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgPacketDelay'], label = 'K = '+K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 3.245, "B = " + B, fontsize=10)
            plt.text(80, 3.225, "p = " + p, fontsize=10)
            plt.text(80, 3.205, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('avgPD'+q+'_p'+p+'_B'+B+'.png')

# %%
for K in ['0.600000']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for q in ['INQ', 'KOUQ', 'iSLIP']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgPacketDelay'], label = 'queue = ' + q)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 4.3, "B = " + B, fontsize=10)
            plt.text(80, 4.1, "K = " + K, fontsize=10)
            plt.text(80, 3.9, "p = " + p, fontsize=10)
            plt.legend()
            plt.savefig('avgPDK'+K+'_p'+p+'_B'+B+'.png')

# %%
for q in ['INQ']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgPacketDelay'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 5.1, "K = " + K, fontsize=10)
            plt.text(80, 4.9, "p = " + p, fontsize=10)
            plt.text(80, 4.7, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('avgPD'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgPacketDelay'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 2.95, "K = " + K, fontsize=10)
            plt.text(80, 2.9, "p = " + p, fontsize=10)
            plt.text(80, 2.85, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('avgPD'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for p in ['0.500000']:
        for K in ['0.600000']:
            plt.figure()
            for B in ['2', '3', '4']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgPacketDelay'], label = 'B = ' + B)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 5.1, "K = " + K, fontsize=10)
            plt.text(80, 4.9, "p = " + p, fontsize=10)
            plt.text(80, 4.7, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('avgPD'+q+'_p'+p+'_K'+K+'.png')

# %%
for q in ['INQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['stdPacketDelay'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('stdPD'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['avgPacketDelay'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('Average Packet Delay')
            plt.text(80, 0.035, "K = " + K, fontsize=10)
            plt.text(80, 0.03, "B = " + B, fontsize=10)
            plt.text(80, 0.025, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('avgPD'+q+'_B'+B+'_K'+K+'.png')

# %% [markdown]
# # KDProb: KOUQ Drop Probability

# %%
for q in ['INQ']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability']*1000, label = 'K = ' + K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(80, 0.58, "B = " + B, fontsize=10)
            plt.text(80, 0.5, "p = " + p, fontsize=10)
            plt.text(80, 0.42, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('KDP'+q+'_p'+p+'_B'+B+'.png')

# %%
for q in ['KOUQ']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability']*1000, label = 'K = ' + K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(45, 0.0340, "B = " + B, fontsize=10)
            plt.text(45, 0.0315, "p = " + p, fontsize=10)
            plt.text(45, 0.0290, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('KDP'+q+'_p'+p+'_B'+B+'.png')

# %%
for q in ['iSLIP']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for K in ['0.600000', '0.800000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability']*1000, label = 'K = ' + K)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(80, 0.6, "B = " + B, fontsize=10)
            plt.text(80, 0.52, "p = " + p, fontsize=10)
            plt.text(80, 0.44, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('KDP'+q+'_p'+p+'_B'+B+'.png')

# %%
for K in ['0.600000']:
    for p in ['0.500000']:
        for B in ['4']:
            plt.figure()
            for q in ['INQ', 'KOUQ', 'iSLIP']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability']*1000, label = 'queue = ' + q)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(80, 0.58, "B = " + B, fontsize=10)
            plt.text(80, 0.42, "K = " + K, fontsize=10)
            plt.text(80, 0.5, "p = " + p, fontsize=10)
            plt.legend()
            plt.savefig('KDPK'+K+'_p'+p+'_B'+B+'.png')

# %%
for q in ['INQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(45, 0.003, "K = " + K, fontsize=10)
            plt.text(45, 0.0025, "B = " + B, fontsize=10)
            plt.text(45, 0.002, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('KDP'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['iSLIP']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(45, 0.003, "K = " + K, fontsize=10)
            plt.text(45, 0.0025, "B = " + B, fontsize=10)
            plt.text(45, 0.002, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('KDP'+q+'_B'+B+'_K'+K+'.png')

# %%
for q in ['KOUQ']:
    for B in ['4']:
        for K in ['0.600000']:
            plt.figure()
            for p in ['0.250000', '0.500000', '0.750000', '1.000000']:
                df = pd.read_csv('final/K'+K+'_p'+p+'_B'+B+'_'+q+'.tsv', sep='\t')
                plt.plot(df['N'],df['KOUQDropProbability'], label = 'p = ' + p)
            plt.xticks(np.arange(0, 101, 10))
            #plt.yticks(np.arange(0, 0.06, 0.01))
            plt.xlabel('Number of Ports (N)')
            plt.ylabel('KOUQ Drop Probability * 1000')
            plt.text(45, 0.0003, "K = " + K, fontsize=10)
            plt.text(45, 0.00025, "B = " + B, fontsize=10)
            plt.text(45, 0.0002, "queue = " + q, fontsize=10)
            plt.legend()
            plt.savefig('KDP'+q+'_B'+B+'_K'+K+'.png')
